# %% [markdown]
# <a href="https://colab.research.google.com/github/donw385/Unit-2-Sprint-Challenge/blob/master/Don_Wang_Predictive_Modeling_Challenge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install category_encoders
# Out:
# ...
#     100% |████████████████████████████████| 61kB 4.0MB/s
# ...

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
import category_encoders as ce
from sklearn.feature_selection import f_regression, SelectKBest
from sklearn.model_selection import GridSearchCV
from google.colab import drive
from sklearn.linear_model import Ridge
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification
from xgboost import XGBClassifier


pd.set_option('display.max_columns', 500)

# %%
# !pip install kaggle

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %env KAGGLE_CONFIG_DIR=/content/drive/My Drive/
# Out:
# env: KAGGLE_CONFIG_DIR=/content/drive/My Drive/

# %%
# !kaggle competitions download -c ds2-predictive-modeling-challenge
# Out:
# ...
#   0% 0.00/3.81M [00:00<?, ?B/s]
# 100% 3.81M/3.81M [00:00<00:00, 125MB/s]
# ...
#   0% 0.00/211k [00:00<?, ?B/s]
# 100% 211k/211k [00:00<00:00, 64.7MB/s]
# ...
#   0% 0.00/948k [00:00<?, ?B/s]
# 100% 948k/948k [00:00<00:00, 131MB/s]
# ...
#   0% 0.00/236k [00:00<?, ?B/s]
# 100% 236k/236k [00:00<00:00, 74.1MB/s]

# %%
# !unzip train_features.csv.zip
# Out:
# Archive:  train_features.csv.zip
#   inflating: train_features.csv

# %%
# !unzip train_labels.csv.zip
# Out:
# Archive:  train_labels.csv.zip
#   inflating: train_labels.csv

# %%
# !unzip test_features.csv.zip
# Out:
# Archive:  test_features.csv.zip
#   inflating: test_features.csv

# %%
train_df = pd.read_csv('train_features.csv')
train_df
# Out:
#           id  amount_tsh date_recorded                    funder  gps_height  \
# 0      69572      6000.0    2011-03-14                     Roman        1390
# 1       8776         0.0    2013-03-06                   Grumeti        1399
# 2      34310        25.0    2013-02-25              Lottery Club         686
# 3      67743         0.0    2013-01-28                    Unicef         263
# 4      19728         0.0    2011-07-13               Action In A           0
# 5       9944        20.0    2011-03-13       Mkinga Distric Coun           0
# 6      19816         0.0    2012-10-01                      Dwsp           0
# 7      54551         0.0    2012-10-09                     Rwssp           0
# 8      53934         0.0    2012-11-03                  Wateraid           0
# 9      46144         0.0    2011-08-03               Isingiro Ho           0
# 10     49056         0.0    2011-02-20                   Private          62
# ...

# %%
train_labels_df = pd.read_csv('train_labels.csv')
train_labels_df
# Out:
#           id             status_group
# 0      69572               functional
# 1       8776               functional
# 2      34310               functional
# 3      67743           non functional
# 4      19728               functional
# 5       9944               functional
# 6      19816           non functional
# 7      54551           non functional
# 8      53934           non functional
# 9      46144               functional
# 10     49056               functional
# 11     50409               functional
# 12     36957               functional
# 13     50495               functional
# 14     53752               functional
# 15     61848               functional
# 16     48451           non functional
# 17     58155           non functional
# 18     34169  functional needs repair
# 19     18274               functional
# 20     48375               functional
# 21      6091               functional
# 22     58500  functional needs repair
# 23     37862               functional
# ...

# %%
train_df.shape, train_labels_df.shape
# Out:
# ((59400, 40), (59400, 2))

# %%
test_df = pd.read_csv('test_features.csv')
test_df
# Out:
#           id  amount_tsh date_recorded                   funder  gps_height  \
# 0      50785         0.0    2013-02-04                     Dmdd        1996
# 1      51630         0.0    2013-02-04   Government Of Tanzania        1569
# 2      17168         0.0    2013-02-01                      NaN        1567
# 3      45559         0.0    2013-01-22               Finn Water         267
# 4      49871       500.0    2013-03-27                   Bruder        1260
# 5      52449         0.0    2013-03-04   Government Of Tanzania        1685
# 6      24806         0.0    2011-03-02   Government Of Tanzania         550
# 7      28965         0.0    2013-01-25                     Finw         234
# 8      36301        30.0    2013-01-23                   Unicef         584
# 9      54122         0.0    2013-03-18  Lawatefuka Water Supply        1083
# 10       419         5.0    2013-10-03          Germany Republi        1259
# ...

# %%
train_df.shape, test_df.shape
# Out:
# ((59400, 40), (14358, 40))

# %%
sample = pd.read_csv('sample_submission.csv')
sample
# Out:
#           id status_group
# 0      50785   functional
# 1      51630   functional
# 2      17168   functional
# 3      45559   functional
# 4      49871   functional
# 5      52449   functional
# 6      24806   functional
# 7      28965   functional
# 8      36301   functional
# 9      54122   functional
# 10       419   functional
# 11     45750   functional
# 12       653   functional
# 13     14017   functional
# 14     40228   functional
# 15     27714   functional
# 16     28785   functional
# 17     18532   functional
# 18     69961   functional
# 19     55083   functional
# 20      8691   functional
# 21     30331   functional
# 22     70970   functional
# 23     61136   functional
# 24     28799   functional
# 25     46825   functional
# 26     44718   functional
# 27     37350   functional
# 28     65738   functional
# 29      3271   functional
# ...      ...          ...
# 14328  73579   functional
# 14329  52228   functional
# 14330  70038   functional
# ...

# %%
train_new = pd.merge(train_df,train_labels_df,how='inner',on='id')
train_new.head()
# Out:
#       id  amount_tsh date_recorded        funder  gps_height     installer  \
# 0  69572      6000.0    2011-03-14         Roman        1390         Roman
# 1   8776         0.0    2013-03-06       Grumeti        1399       GRUMETI
# 2  34310        25.0    2013-02-25  Lottery Club         686  World vision
# 3  67743         0.0    2013-01-28        Unicef         263        UNICEF
# 4  19728         0.0    2011-07-13   Action In A           0       Artisan
#
#    longitude   latitude              wpt_name  num_private  \
# 0  34.938093  -9.856322                  none            0
# 1  34.698766  -2.147466              Zahanati            0
# 2  37.460664  -3.821329           Kwa Mahundi            0
# 3  38.486161 -11.155298  Zahanati Ya Nanyumbu            0
# 4  31.130847  -1.825359               Shuleni            0
#
#                      basin  subvillage   region  region_code  district_code  \
# 0               Lake Nyasa    Mnyusi B   Iringa           11              5
# ...

# %%
dict = {'functional':1,'non functional':2,'functional needs repair':3}
train_new['status_number'] = train_new['status_group'].map(dict)


train_new
# Out:
#           id  amount_tsh date_recorded                    funder  gps_height  \
# 0      69572      6000.0    2011-03-14                     Roman        1390
# 1       8776         0.0    2013-03-06                   Grumeti        1399
# 2      34310        25.0    2013-02-25              Lottery Club         686
# 3      67743         0.0    2013-01-28                    Unicef         263
# 4      19728         0.0    2011-07-13               Action In A           0
# 5       9944        20.0    2011-03-13       Mkinga Distric Coun           0
# 6      19816         0.0    2012-10-01                      Dwsp           0
# 7      54551         0.0    2012-10-09                     Rwssp           0
# 8      53934         0.0    2012-11-03                  Wateraid           0
# 9      46144         0.0    2011-08-03               Isingiro Ho           0
# 10     49056         0.0    2011-02-20                   Private          62
# ...

# %%
train_new.isnull().sum()
# Out:
# id                           0
# amount_tsh                   0
# date_recorded                0
# funder                    3635
# gps_height                   0
# installer                 3655
# longitude                    0
# latitude                     0
# wpt_name                     0
# num_private                  0
# basin                        0
# subvillage                 371
# region                       0
# region_code                  0
# district_code                0
# lga                          0
# ward                         0
# population                   0
# public_meeting            3334
# recorded_by                  0
# scheme_management         3877
# scheme_name              28166
# permit                    3056
# construction_year            0
# extraction_type              0
# extraction_type_group        0
# extraction_type_class        0
# management                   0
# management_group             0
# payment                      0
# ...

# %%
train_new.select_dtypes(exclude=np.number).nunique()
# Out:
# date_recorded              356
# funder                    1897
# installer                 2145
# wpt_name                 37400
# basin                        9
# subvillage               19287
# region                      21
# lga                        125
# ward                      2092
# public_meeting               2
# recorded_by                  1
# scheme_management           12
# scheme_name               2696
# permit                       2
# extraction_type             18
# extraction_type_group       13
# extraction_type_class        7
# management                  12
# management_group             5
# payment                      7
# payment_type                 7
# water_quality                8
# quality_group                6
# quantity                     5
# quantity_group               5
# source                      10
# source_type                  7
# source_class                 3
# waterpoint_type              7
# waterpoint_type_group        6
# ...

# %%
# drop high cardinality columns

y_train =  train_new['status_number']
X_train = train_new.drop(columns=['status_number','status_group','id','scheme_name','ward', 'subvillage', 'wpt_name', 'installer', 'funder', 'date_recorded'])
X_test  = test_df.drop(columns=['id','scheme_name','ward', 'subvillage', 'wpt_name', 'installer', 'funder', 'date_recorded'])

# %%
train_new.info()

# %%
pipeline = make_pipeline(
    ce.OneHotEncoder(use_cat_names=True), 
    StandardScaler(),  
    RandomForestClassifier(class_weight='balanced', 
                            n_jobs=-1, 
                            n_estimators=1000))

pipeline.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /usr/local/lib/python3.6/dist-packages/sklearn/base.py:467: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# Pipeline(memory=None,
#      steps=[('onehotencoder', OneHotEncoder(cols=['basin', 'region', 'lga', 'public_meeting', 'recorded_by', 'scheme_management', 'permit', 'extraction_type', 'extraction_type_group', 'extraction_type_class', 'management', 'management_group', 'payment', 'payment_type', 'water_quality', 'quality_group', '...tors=1000, n_jobs=-1, oob_score=False,
#             random_state=None, verbose=0, warm_start=False))])

# %%
# pipeline = make_pipeline(
#     ce.OneHotEncoder(use_cat_names=True), 
#     StandardScaler(),  
#     Ridge())



# pipeline.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /usr/local/lib/python3.6/dist-packages/sklearn/base.py:467: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# Pipeline(memory=None,
#      steps=[('onehotencoder', OneHotEncoder(cols=['basin', 'region', 'lga', 'public_meeting', 'recorded_by', 'scheme_management', 'permit', 'extraction_type', 'extraction_type_group', 'extraction_type_class', 'management', 'management_group', 'payment', 'payment_type', 'water_quality', 'quality_group', '...it_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001))])

# %%
# took too long, did not improve score

# param_grid = {'logisticregression__class_weight':[None,'balanced'],'logisticregression__C':[.0001, .001, .01, .1, 1.0, 10.0, 100.00, 1000.0, 10000.0]}

# gs = GridSearchCV(pipeline,param_grid,cv=5,scoring='accuracy')
# gs.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /usr/local/lib/python3.6/dist-packages/sklearn/base.py:467: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/pipeline.py:331: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# ...

# %%
y_pred = pipeline.predict(X_test)

pd.DataFrame(y_pred)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/pipeline.py:331: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
#        0
# 0      1
# 1      1
# 2      1
# 3      2
# 4      1
# 5      1
# 6      1
# 7      2
# 8      2
# 9      1
# 10     1
# 11     2
# 12     2
# 13     2
# 14     1
# 15     1
# 16     1
# 17     2
# 18     1
# 19     2
# 20     2
# 21     2
# 22     1
# 23     1
# 24     2
# 25     2
# 26     3
# 27     1
# 28     1
# 29     2
# ...   ..
# 14328  2
# 14329  3
# 14330  1
# 14331  1
# 14332  2
# 14333  1
# 14334  1
# 14335  2
# 14336  2
# 14337  1
# 14338  2
# 14339  1
# 14340  1
# 14341  1
# 14342  3
# 14343  1
# 14344  1
# 14345  2
# 14346  1
# 14347  1
# 14348  1
# 14349  1
# 14350  3
# 14351  1
# 14352  1
# 14353  2
# 14354  1
# 14355  1
# 14356  1
# 14357  2
#
# [14358 rows x 1 columns]

# %%
# submission
submission = sample.copy()
submission['y5']= y_pred

# %%
dict2 = {1:'functional',2:'non functional',3:'functional needs repair'}
submission['status_new'] = submission['y5'].map(dict2)


submission
# Out:
#           id status_group  y5               status_new
# 0      50785   functional   1               functional
# 1      51630   functional   1               functional
# 2      17168   functional   1               functional
# 3      45559   functional   2           non functional
# 4      49871   functional   1               functional
# 5      52449   functional   1               functional
# 6      24806   functional   1               functional
# 7      28965   functional   2           non functional
# 8      36301   functional   2           non functional
# 9      54122   functional   1               functional
# 10       419   functional   1               functional
# 11     45750   functional   2           non functional
# 12       653   functional   2           non functional
# 13     14017   functional   2           non functional
# 14     40228   functional   1               functional
# 15     27714   functional   1               functional
# ...

# %%
drive.mount('drive', force_remount=True)
# Out:
# Mounted at drive

# %%
submission.to_csv('submission-005.csv',index=False)
# !cp submission-005.csv drive/My\ Drive/

# %% [markdown]
# # New Section

# %%
submission
# Out:
#           id status_group                       y3
# 0      50785   functional           non functional
# 1      51630   functional               functional
# 2      17168   functional               functional
# 3      45559   functional           non functional
# 4      49871   functional               functional
# 5      52449   functional               functional
# 6      24806   functional               functional
# 7      28965   functional           non functional
# 8      36301   functional           non functional
# 9      54122   functional               functional
# 10       419   functional               functional
# 11     45750   functional           non functional
# 12       653   functional           non functional
# 13     14017   functional               functional
# 14     40228   functional               functional
# 15     27714   functional               functional
# 16     28785   functional               functional
# ...

# %%
submission['y3'].value_counts()
# Out:
# functional                 9409
# non functional             4785
# functional needs repair     164
# Name: y3, dtype: int64
